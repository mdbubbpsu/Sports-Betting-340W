# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error 
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
df = pd.read_csv('/Users/mattbubb/Spring_2021/DS_340W/Sports-Betting-340W/Data/upToDateStats.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 abbreviation     team_id is_home   season   game_date  \
# 0           0          ATL  1610612737       t  2003-04  2003-11-01
# 1           1          ATL  1610612737       t  2003-04  2003-11-03
# 2           2          ATL  1610612737       f  2003-04  2003-11-05
# 3           3          ATL  1610612737       f  2003-04  2003-11-08
# 4           4          ATL  1610612737       f  2003-04  2003-11-09
#
#    ShiftedGameNumber  ShiftedGameID         w         l  ...    ft_pct  \
# 0                  2       20300042  0.000000  3.000000  ...  1.000000
# 1                  3       20300060  0.500000  3.000000  ...  1.000000
# 2                  4       20300084  0.666667  3.333333  ...  0.666667
# 3                  5       20300089  0.750000  3.750000  ...  0.750000
# 4                  6       20300102  1.000000  4.000000  ...  0.800000
#
#         oreb       dreb   reb        ast       stl       blk        tov  \
# 0   4.000000  32.000000  36.0  23.000000  5.000000  9.000000  16.000000
# 1  11.000000  32.000000  43.0  21.500000  5.500000  8.000000  15.500000
# 2  11.666667  31.333333  43.0  20.666667  6.333333  6.666667  16.666667
# 3  11.750000  31.750000  43.5  20.750000  6.250000  6.750000  16.000000
# 4  11.200000  31.800000  43.0  19.800000  7.400000  6.800000  17.000000
#
#           pf   pts
# 0  27.000000  99.0
# 1  24.500000  94.5
# 2  24.666667  87.0
# 3  21.250000  86.0
# 4  20.400000  87.0
#
# [5 rows x 30 columns]

# %%
df.sorted_values('')
# Out:
#        Unnamed: 0 abbreviation     team_id is_home   season   game_date  \
# 0               0          ATL  1610612737       t  2003-04  2003-11-01
# 1               1          ATL  1610612737       t  2003-04  2003-11-03
# 2               2          ATL  1610612737       f  2003-04  2003-11-05
# 3               3          ATL  1610612737       f  2003-04  2003-11-08
# 4               4          ATL  1610612737       f  2003-04  2003-11-09
# ...           ...          ...         ...     ...      ...         ...
# 37227       37698          WAS  1610612764       f  2017-18  2018-04-14
# 37228       37699          WAS  1610612764       f  2017-18  2018-04-17
# 37229       37700          WAS  1610612764       t  2017-18  2018-04-20
# 37230       37701          WAS  1610612764       t  2017-18  2018-04-22
# 37231       37702          WAS  1610612764       f  2017-18  2018-04-25
#
#        ShiftedGameNumber  ShiftedGameID          w          l  ...    ft_pct  \
# 0                      2       20300042   0.000000   3.000000  ...  1.000000
# 1                      3       20300060   0.500000   3.000000  ...  1.000000
# 2                      4       20300084   0.666667   3.333333  ...  0.666667
# 3                      5       20300089   0.750000   3.750000  ...  0.750000
# 4                      6       20300102   1.000000   4.000000  ...  0.800000
# ...                  ...            ...        ...        ...  ...       ...
# 37227                 78       41700102  24.545455  19.389610  ...  0.987013
# 37228                 79       41700103  24.230769  19.166667  ...  0.987179
# 37229                 80       41700104  23.936709  18.949367  ...  0.987342
# 37230                 81       41700105  23.662500  18.737500  ...  0.987500
# 37231                 82       41700106  23.395062  18.543210  ...  0.987654
#
#             oreb       dreb        reb        ast       stl       blk  \
# 0       4.000000  32.000000  36.000000  23.000000  5.000000  9.000000
# 1      11.000000  32.000000  43.000000  21.500000  5.500000  8.000000
# 2      11.666667  31.333333  43.000000  20.666667  6.333333  6.666667
# 3      11.750000  31.750000  43.500000  20.750000  6.250000  6.750000
# 4      11.200000  31.800000  43.000000  19.800000  7.400000  6.800000
# ...          ...        ...        ...        ...       ...       ...
# 37227   9.922078  33.051948  42.974026  25.272727  7.740260  4.181818
# 37228   9.846154  33.012821  42.858974  25.282051  7.730769  4.166667
# 37229   9.810127  33.000000  42.810127  25.329114  7.759494  4.215190
# 37230   9.800000  32.975000  42.775000  25.300000  7.787500  4.262500
# 37231   9.851852  33.012346  42.864198  25.246914  7.765432  4.259259
#
#              tov         pf         pts
# 0      16.000000  27.000000   99.000000
# 1      15.500000  24.500000   94.500000
# 2      16.666667  24.666667   87.000000
# 3      16.000000  21.250000   86.000000
# 4      17.000000  20.400000   87.000000
# ...          ...        ...         ...
# 37227  14.064935  21.389610  106.207792
# 37228  13.987179  21.423077  106.371795
# 37229  13.949367  21.417722  106.569620
# 37230  13.937500  21.437500  106.562500
# 37231  13.950617  21.395062  106.456790
#
# [37232 rows x 30 columns]

# %%
df.columns
# Out:
# Index(['team1_team_id', 'book_id', 'home_team_id', 'home_w_pct', 'home_fg_pct',
#        'home_fg3_pct', 'home_ft_pct', 'home_reb', 'home_ast', 'home_stl',
#        'home_blk', 'home_tov', 'home_pts', 'away_team_id', 'away_w_pct',
#        'away_fg_pct', 'away_fg3_pct', 'away_ft_pct', 'away_reb', 'away_ast',
#        'away_stl', 'away_blk', 'away_tov', 'away_pts', 'homeTeamPrice',
#        'awayTeamPrice', 'reb_diff', 'diff_reb', 'diff_fg_pct', 'diff_fg3_pct',
#        'diff_w_pct', 'diff_pts', 'diff_ast', 'diff_tov'],
#       dtype='object')

# %%
df.describe()
# Out:
#        team1_team_id        book_id  home_team_id     home_w_pct  \
# count   1.067510e+05  106751.000000  1.067510e+05  106751.000000
# mean    1.610613e+09  192039.061255  1.610613e+09       0.504403
# std     8.653594e+00  393481.895532  5.223163e+01       0.188052
# min     1.610613e+09      19.000000  1.610613e+09       0.000000
# 25%     1.610613e+09     139.000000  1.610613e+09       0.375000
# 50%     1.610613e+09     238.000000  1.610613e+09       0.500000
# 75%     1.610613e+09    1275.000000  1.610613e+09       0.627000
# max     1.610613e+09  999996.000000  1.610617e+09       1.000000
#
#          home_fg_pct   home_fg3_pct    home_ft_pct       home_reb  \
# count  106751.000000  106751.000000  106751.000000  106751.000000
# mean        0.722008       0.356166       0.987298      42.748677
# std         0.277166       0.110407       0.111988       6.499914
# min         0.000000       0.000000       0.000000      17.000000
# 25%         0.458000       0.286000       1.000000      38.000000
# 50%         0.578000       0.355000       1.000000      43.000000
# 75%         1.000000       0.429000       1.000000      47.000000
# max         1.000000       1.000000       1.000000      72.000000
#
#             home_ast       home_stl  ...   away_fg3_pct    away_ft_pct  \
# count  106751.000000  106751.000000  ...  106751.000000  106751.000000
# mean       22.225066       7.574046  ...       0.352114       0.982726
# std         5.143671       2.900567  ...       0.109903       0.130291
# min         6.000000       0.000000  ...       0.000000       0.000000
# 25%        19.000000       6.000000  ...       0.280000       1.000000
# 50%        22.000000       7.000000  ...       0.353000       1.000000
# 75%        26.000000       9.000000  ...       0.423000       1.000000
# max        47.000000      21.000000  ...       1.000000       1.000000
#
#             away_reb       away_ast       away_stl       away_blk  \
# count  106751.000000  106751.000000  106751.000000  106751.000000
# mean       42.123811      21.456502       7.542131       4.710270
# std         6.463119       5.026619       2.889254       2.490883
# min        21.000000       4.000000       0.000000       0.000000
# 25%        38.000000      18.000000       6.000000       3.000000
# 50%        42.000000      21.000000       7.000000       4.000000
# 75%        46.000000      25.000000       9.000000       6.000000
# max        81.000000      46.000000      20.000000      17.000000
#
#             away_tov       away_pts  homeTeamPrice  awayTeamPrice
# count  106751.000000  106751.000000  106751.000000  106751.000000
# mean       13.728152     100.098575    -234.903195     130.160664
# std         3.841900      12.347876     577.027736     407.614328
# min         2.000000      56.000000  -13131.000000  -11450.000000
# 25%        11.000000      92.000000    -345.000000    -139.000000
# 50%        14.000000     100.000000    -175.000000     156.000000
# 75%        16.000000     108.000000     120.000000     285.000000
# max        28.000000     154.000000    6725.000000    6500.000000
#
# [8 rows x 26 columns]

# %%
df['diff_reb'] = df['home_reb'] - df['away_reb']
df['diff_fg_pct'] = df['home_fg_pct'] - df['away_fg_pct']
df['diff_fg3_pct'] = df['home_fg_pct'] - df['away_fg_pct']
df['diff_w_pct'] = df['home_w_pct'] - df['away_w_pct']
df['diff_pts'] = df['home_pts'] - df['away_pts']
df['diff_ast'] = df['home_ast'] - df['away_ast']
df['diff_pts'] = df['home_pts'] - df['away_pts']
df['diff_tov'] = df['home_tov'] - df['away_tov']

# %%
X = df[['home_w_pct', 'home_fg_pct',
        'home_fg3_pct', 'home_ft_pct', 'home_reb', 'home_ast', 'home_stl',
       'home_blk', 'home_tov', 'home_pts', 'away_team_id', 'away_w_pct',
       'away_fg_pct', 'away_fg3_pct', 'away_ft_pct', 'away_reb', 'away_ast',
       'away_stl', 'away_blk', 'away_tov', 'away_pts', 'reb_diff', 'diff_reb', 
       'diff_fg_pct', 'diff_fg3_pct',
       'diff_w_pct', 'diff_pts', 'diff_ast', 'diff_tov']]
yHome = df['homeTeamPrice']
yAway = df['awayTeamPrice']

# %% [markdown]
# ## Parson's Correlation on Features

# %%
plt.figure(figsize=(30,25))
cor = df.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# ## Hometeam Price Feature Investigation

# %%
#Correlation with home team price variable
cor_target_home = abs(cor["homeTeamPrice"])
cor_target_home.sort_values(ascending=False)
# Out:
# homeTeamPrice    1.000000
# awayTeamPrice    0.885689
# diff_pts         0.068733
# home_blk         0.068099
# home_ast         0.062915
# home_pts         0.058095
# diff_ast         0.053711
# book_id          0.046641
# diff_reb         0.043576
# reb_diff         0.043576
# home_stl         0.034890
# home_reb         0.033398
# away_pts         0.030086
# away_reb         0.025521
# home_fg3_pct     0.023102
# home_w_pct       0.023037
# away_w_pct       0.022828
# diff_fg_pct      0.020068
# diff_fg3_pct     0.020068
# away_tov         0.013589
# away_blk         0.013578
# diff_tov         0.008862
# away_stl         0.007212
# home_fg_pct      0.006719
# away_ft_pct      0.006119
# away_ast         0.005932
# home_team_id     0.004372
# away_fg3_pct     0.003154
# away_fg_pct      0.002825
# home_tov         0.001700
# home_ft_pct      0.001541
# away_team_id     0.000596
# team1_team_id    0.000487
# diff_w_pct       0.000184
# Name: homeTeamPrice, dtype: float64

# %%
reg = LassoCV()
reg.fit(X, yHome)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,yHome))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# c:\users\jorda\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Best alpha using built-in LassoCV: 21.995284
# Best score using built-in LassoCV: 0.011669

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 10 variables and eliminated the other 19 variables

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %% [markdown]
# ## Awayteam Price Investigation

# %%
#Correlation with away team price variable
cor_target_away = abs(cor["awayTeamPrice"])
cor_target_away.sort_values(ascending=False)
# Out:
# awayTeamPrice    1.000000
# homeTeamPrice    0.885689
# home_blk         0.071366
# diff_pts         0.071290
# diff_ast         0.058935
# diff_reb         0.056471
# reb_diff         0.056471
# home_pts         0.050098
# home_ast         0.048529
# away_reb         0.042345
# away_pts         0.041317
# book_id          0.039261
# home_reb         0.034062
# away_ast         0.027491
# home_stl         0.027191
# diff_fg_pct      0.024122
# diff_fg3_pct     0.024122
# away_blk         0.021743
# home_w_pct       0.021700
# home_fg3_pct     0.021143
# away_w_pct       0.019410
# home_fg_pct      0.013466
# home_ft_pct      0.006841
# diff_tov         0.005931
# home_team_id     0.005831
# away_stl         0.005785
# team1_team_id    0.005444
# away_ft_pct      0.005183
# away_tov         0.004833
# diff_w_pct       0.003462
# home_tov         0.003179
# away_fg3_pct     0.002066
# away_team_id     0.001938
# away_fg_pct      0.001911
# Name: awayTeamPrice, dtype: float64

# %%
reg = LassoCV()
reg.fit(X, yAway)
print("Best alpha using built-in LassoCV: %f" % reg.alpha_)
print("Best score using built-in LassoCV: %f" %reg.score(X,yAway))
coef = pd.Series(reg.coef_, index = X.columns)
# Out:
# c:\users\jorda\appdata\local\programs\python\python37\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# Best alpha using built-in LassoCV: 14.016377
# Best score using built-in LassoCV: 0.012765

# %%
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  str(sum(coef == 0)) + " variables")
# Out:
# Lasso picked 10 variables and eliminated the other 19 variables

# %%
imp_coef = coef.sort_values()
import matplotlib
matplotlib.rcParams['figure.figsize'] = (8.0, 10.0)
imp_coef.plot(kind = "barh")
plt.title("Feature importance using Lasso Model")
# Out:
# Text(0.5, 1.0, 'Feature importance using Lasso Model')

# %% [markdown]
# ## Back to modeling

# %%
X = df[['home_blk','home_stl','reb_diff','diff_pts','diff_ast','home_ast','away_reb','away_blk']]
y = df[['homeTeamPrice','awayTeamPrice']]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=0.3, random_state=4)

# %%
regr_multirf = MultiOutputRegressor(RandomForestRegressor(n_estimators=100,
                                                          max_depth=30,
                                                          random_state=0))
regr_multirf.fit(X_train, y_train)
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(bootstrap=True,
#                                                      criterion='mse',
#                                                      max_depth=30,
#                                                      max_features='auto',
#                                                      max_leaf_nodes=None,
#                                                      min_impurity_decrease=0.0,
#                                                      min_impurity_split=None,
#                                                      min_samples_leaf=1,
#                                                      min_samples_split=2,
#                                                      min_weight_fraction_leaf=0.0,
#                                                      n_estimators=100,
#                                                      n_jobs=None,
#                                                      oob_score=False,
#                                                      random_state=0, verbose=0,
#                                                      warm_start=False),
#                      n_jobs=None)

# %%
y_multirf = regr_multirf.predict(X_test)

# %%
regr_multirf.score(X_test, y_test)
# Out:
# 0.7621871228673494

# %%
y_multirf = pd.DataFrame(y_multirf, columns = ['homeTeamPrice','awayTeamPrice'])

# %% [markdown]
# ## Performance Metrics

# %%
homeRMSE = math.sqrt(mean_squared_error(y_multirf['homeTeamPrice'], y_test['homeTeamPrice']))

# %%
homeRMSE
# Out:
# 293.6326988637844

# %%
y_multirf['homeTeamPrice'][:5]
# Out:
# 0     25.549690
# 1   -259.695635
# 2   -167.814781
# 3    119.248850
# 4   -108.445980
# Name: homeTeamPrice, dtype: float64

# %%
y_test['homeTeamPrice'][:5]
# Out:
# 58640     105.0
# 100887    540.0
# 52038    -154.0
# 4421      130.0
# 17735    -105.0
# Name: homeTeamPrice, dtype: float64

# %%
awayRMSE = math.sqrt(mean_squared_error(y_multirf['awayTeamPrice'], y_test['awayTeamPrice']))

# %%
awayRMSE
# Out:
# 191.19211031444297

# %%
y_multirf['awayTeamPrice'][:5]
# Out:
# 0    -86.160603
# 1   -130.378730
# 2    123.631305
# 3   -147.555446
# 4    -57.924769
# Name: awayTeamPrice, dtype: float64

# %%
y_test['awayTeamPrice'][:5]
# Out:
# 58640    -125.0
# 100887   -600.0
# 52038     134.0
# 4421     -150.0
# 17735    -115.0
# Name: awayTeamPrice, dtype: float64
